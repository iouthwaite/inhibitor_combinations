# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import os

def import_from_excel(e_file, filename):
    kinase_targets = e_file['kinase target'].tolist()
    JS_scores = e_file['JS Distance Score'].tolist()
    inhibitors = e_file['inhibitors']
    ot_effect = e_file['Target kinase %inhib']
    mu = int(filename.split('.')[0].split('_')[-2])
    return [mu, kinase_targets, JS_scores, inhibitors,ot_effect]

test_results_200 = []
test_results_700 = []

for filename in os.listdir(os.getcwd()+'/inhibitor_scoring_results/'):
    f = './inhibitor_scoring_results/'+str(filename)
    open_file = pd.read_excel(f, '1')
    res = import_from_excel(open_file, filename)
    if res[0] == 200:
        test_results_200 = res
    if res[0] == 700:
        test_results_700 = res
        
#set up the list of all kinase names for our result matrix
PKIS2_data=pd.read_excel("PKIS2_dataset.xlsx")
kinase_names = list(PKIS2_data.columns.values)[7:]
num_kinases = len(kinase_names)
# Out:
# /usr/local/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
#get the scores of every inhibitor against every kinase 
inhibitor_names = []

result_array = []

KT_200 = test_results_200[1]
I_200 = test_results_200[3]
JSD_200 = test_results_200[2]
OT_200 = test_results_200[4]

#set up the array
unique_inhibitor_names = list(set(I_200))
for h in range(0, len(unique_inhibitor_names)):
    result_array.append([])
    i_name = unique_inhibitor_names[h][2:-2]
    inhibitor_names.append(i_name)
    for j in range(num_kinases):
        result_array[h].append(None)

#fill the array - score is the JSD (a measure of the off-target selectivity) * the on-target % inhibition
for x in range(0, len(KT_200)):
    I = I_200[x][2:-2]
    KT = KT_200[x]
    JSD = JSD_200[x]
    OT_effect = OT_200[x]
    score = JSD * OT_effect
    I_index = inhibitor_names.index(I)
    KT_index = kinase_names.index(KT)
    result_array[I_index][KT_index] = score
    
res_arr = np.array(result_array, dtype=object)

#same thing, for mu=700

KT_700 = test_results_700[1]
I_700 = test_results_700[3]
JSD_700 = test_results_700[2]
OT_700 = test_results_700[4]

inhibitor_names2 = []
result_array2 = []

#set up the array
unique_inhibitor_names2 = list(set(I_700))
for h in range(0, len(unique_inhibitor_names2)):
    result_array2.append([])
    i_name = unique_inhibitor_names2[h][2:-2]
    inhibitor_names2.append(i_name)
    for j in range(num_kinases):
        result_array2[h].append(None)

#fill the array - score is the JSD (a measure of the off-target selectivity) * the on-target % inhibition
for x in range(0, len(KT_700)):
    I = I_700[x][2:-2]
    KT = KT_700[x]
    JSD = JSD_700[x]
    OT_effect = OT_700[x]
    score = JSD * OT_effect
    I_index = inhibitor_names2.index(I)
    KT_index = kinase_names.index(KT)
    result_array2[I_index][KT_index] = score
    
res_arr2 = np.array(result_array2, dtype=object)

# %%
#  now that we have the JSD score array, normalize the score for each inhibitor against 
#  a) each inhibitor's maximum or 
#  b) each kinase's maximum score

'''
#A - how selective is an inhibitor for a kinase relative to its activity against other kinases?
scores_norm_imax = np.copy(res_arr)
for i in range(0,len(scores_norm_imax)):
    scores = [x for x in scores_norm_imax[i] if x != None]
    max_score = np.max(scores)
    min_score = np.min(scores)
    for j in range(0, len(scores_norm_imax[i])):
        if scores_norm_imax[i][j] != None:
            scores_norm_imax[i][j] = (scores_norm_imax[i][j] - min_score) / (max_score - min_score)
'''

#B - how selective is an inhibitor to a kinase relative to other inhibitors that also target that kinase? At mu=200
scores_norm_kmax = np.copy(res_arr)
for j in range(0,len(scores_norm_kmax[0])):
    col = scores_norm_kmax[:, j]
    scores = [x for x in col if x != None]
    if len(scores) > 0:
        max_score = np.max(scores)
        min_score = np.min(scores)
        for i in range(0, len(scores_norm_kmax)):
            if scores_norm_kmax[i][j] != None:
                scores_norm_kmax[i][j] = (scores_norm_kmax[i][j] - min_score) / (max_score - min_score)
 
#B - how selective is an inhibitor to a kinase relative to other inhibitors that also target that kinase? At mu=700
scores_norm_kmax2 = np.copy(res_arr2)
for j in range(0,len(scores_norm_kmax2[0])):
    col = scores_norm_kmax2[:, j]
    scores = [x for x in col if x != None]
    if len(scores) > 0:
        max_score = np.max(scores)
        min_score = np.min(scores)
        for i in range(0, len(scores_norm_kmax2)):
            if scores_norm_kmax2[i][j] != None:
                scores_norm_kmax2[i][j] = (scores_norm_kmax2[i][j] - min_score) / (max_score - min_score)

# %%
#output the results to a table
import pandas as pd

result_list = []
header = ['Inhibitor'] + kinase_names
#result_list.append(header)
for i in range(0, len(scores_norm_kmax)):
    inhibitor_name = inhibitor_names[i]
    data = [inhibitor_name] + list(scores_norm_kmax[i])
    result_list.append(data)
df = pd.DataFrame(result_list, columns=header)
print(df)
df.to_csv("inhibitor_selectivity_scores_mu200.csv",index=False)

result_list2 = []
header = ['Inhibitor'] + kinase_names
#result_list.append(header)
for i in range(0, len(scores_norm_kmax2)):
    inhibitor_name = inhibitor_names2[i]
    data = [inhibitor_name] + list(scores_norm_kmax2[i])
    result_list2.append(data)
df2 = pd.DataFrame(result_list2, columns=header)
print(df2)
df2.to_csv("inhibitor_selectivity_scores_mu700.csv",index=False)
# Out:
#         Inhibitor      AAK1  ABL1-nonphosphorylated  ABL1-phosphorylated  \
# 0    UNC10225216A  0.000000                0.000000             0.000000
# 1    UNC10225139A  0.000000                0.000000             0.000000
# 2        TPKI-113  0.212183                0.974342             0.571143
# 3    UNC10225303A  0.000000                0.100574             0.000000
# 4    UNC10225023A  0.478976                0.000000             0.067439
# ..            ...       ...                     ...                  ...
# 640       TPKI-55  0.000000                0.338604             0.000000
# 641  UNC10225463A  0.255064                0.000000             0.000000
# 642  UNC10225497A  0.019174                0.000000             0.100238
# 643  UNC10225351A  0.000000                0.000000             0.000000
# 644  UNC10225054A  0.051964                0.718163             0.108672
#
#          ABL2     ACVR1    ACVR1B    ACVR2A    ACVR2B    ACVRL1  ...  \
# 0    0.000000  0.000000  0.140026  0.155849  0.000000  0.291107  ...
# 1    0.029999  0.000000  0.038614  0.000000  0.000000  0.102127  ...
# 2    0.701503  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# 3    0.010288  0.000000  0.198678  0.028748  0.186227  0.186855  ...
# 4    0.170383  0.000000  0.022448  0.000000  0.014018  0.000000  ...
# ..        ...       ...       ...       ...       ...       ...  ...
# 640  0.000000  0.000000  0.000000  0.000000  0.080728  0.000000  ...
# 641  0.081847  0.203585  0.000000  0.000000  0.000000  0.000000  ...
# 642  0.103771  0.206280  0.020047  0.154619  0.150200  0.270776  ...
# 643  0.000000  0.000000  0.216211  0.000000  0.000000  0.114319  ...
# 644  0.056254  0.067677  0.000000  0.000000  0.118689  0.000000  ...
#
#         YANK3       YES      YSK1  YSK4       ZAK     ZAP70  p38-alpha  \
# 0    0.358787  0.000000  0.000000  None  0.288668  0.000000   0.000000
# 1    0.282565  0.000000  0.000000  None  0.000000  0.000000   0.000000
# 2    0.243466  0.810783  0.000000  None  0.157090  0.000000   0.782414
# 3    0.000000  0.000000  0.000000  None  0.190286  0.000000   0.018580
# 4    0.060424  0.083812  0.243840  None  0.128978  0.000000   0.000000
# ..        ...       ...       ...   ...       ...       ...        ...
# 640  0.028950  0.000000  0.000000  None  0.000000  0.036167   0.000000
# 641  0.000000  0.150648  0.080454  None  0.000000  0.000000   0.036950
# 642  0.070772  0.264910  0.000000  None  0.162953  0.000000   0.000000
# 643  0.000000  0.000000  0.110103  None  0.000000  0.000000   0.475068
# 644  0.291880  0.441709  0.018433  None  0.669478  0.000000   0.168973
#
#      p38-beta  p38-delta  p38-gamma
# 0    0.121650   0.135522   0.000000
# 1    0.054511   0.000000   0.000000
# 2    0.172814   0.187784   0.000000
# 3    0.065411   0.216206   0.000000
# 4    0.000000   0.555462   0.237652
# ..        ...        ...        ...
# 640  0.000000   0.426955   0.104779
# 641  0.000000   0.497352   0.433039
# 642  0.018848   0.240805   0.000000
# 643  0.152624   0.000000   0.082994
# 644  0.000000   0.000000   0.000000
#
# [645 rows x 407 columns]
#         Inhibitor      AAK1  ABL1-nonphosphorylated  ABL1-phosphorylated  \
# 0    UNC10225216A  0.000000                0.000000             0.000000
# 1    UNC10225139A  0.000000                0.000000             0.000000
# 2        TPKI-113  0.199851                0.915578             0.545215
# 3    UNC10225303A  0.000000                0.098450             0.000000
# 4    UNC10225023A  0.388843                0.000000             0.055371
# ..            ...       ...                     ...                  ...
# 640       TPKI-55  0.000000                0.323069             0.000000
# 641  UNC10225463A  0.245157                0.000000             0.000000
# 642  UNC10225497A  0.018818                0.000000             0.099776
# 643  UNC10225351A  0.000000                0.000000             0.000000
# 644  UNC10225054A  0.047901                0.663565             0.101691
#
#          ABL2     ACVR1    ACVR1B    ACVR2A    ACVR2B    ACVRL1  ...  \
# 0    0.000000  0.000000  0.145309  0.157814  0.000000  0.309638  ...
# 1    0.029342  0.000000  0.038233  0.000000  0.000000  0.103746  ...
# 2    0.687737  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# 3    0.010482  0.000000  0.204839  0.028841  0.185377  0.197174  ...
# 4    0.142904  0.000000  0.019038  0.000000  0.011542  0.000000  ...
# ..        ...       ...       ...       ...       ...       ...  ...
# 640  0.000000  0.000000  0.000000  0.000000  0.077923  0.000000  ...
# 641  0.081444  0.194237  0.000000  0.000000  0.000000  0.000000  ...
# 642  0.105694  0.201312  0.020702  0.155749  0.149721  0.286363  ...
# 643  0.000000  0.000000  0.225684  0.000000  0.000000  0.122368  ...
# 644  0.053869  0.062235  0.000000  0.000000  0.111383  0.000000  ...
#
#         YANK3       YES      YSK1  YSK4       ZAK    ZAP70  p38-alpha  \
# 0    0.352216  0.000000  0.000000  None  0.283519  0.00000   0.000000
# 1    0.264503  0.000000  0.000000  None  0.000000  0.00000   0.000000
# 2    0.227647  0.794992  0.000000  None  0.146875  0.00000   0.737585
# 3    0.000000  0.000000  0.000000  None  0.186047  0.00000   0.018236
# 4    0.048495  0.070210  0.202993  None  0.103998  0.00000   0.000000
# ..        ...       ...       ...   ...       ...      ...        ...
# 640  0.027306  0.000000  0.000000  None  0.000000  0.03585   0.000000
# 641  0.000000  0.150619  0.079508  None  0.000000  0.00000   0.035534
# 642  0.069129  0.270579  0.000000  None  0.159263  0.00000   0.000000
# 643  0.000000  0.000000  0.112981  None  0.000000  0.00000   0.473548
# 644  0.268342  0.426419  0.017520  None  0.617408  0.00000   0.156335
#
#      p38-beta  p38-delta  p38-gamma
# 0    0.121823   0.142575   0.000000
# 1    0.052137   0.000000   0.000000
# 2    0.164930   0.188285   0.000000
# 3    0.065093   0.225551   0.000000
# 4    0.000000   0.480922   0.187789
# ..        ...        ...        ...
# 640  0.000000   0.433030   0.097293
# 641  0.000000   0.509240   0.405350
# 642  0.018812   0.251540   0.000000
# 643  0.153690   0.000000   0.080335
# 644  0.000000   0.000000   0.000000
#
# [645 rows x 407 columns]
